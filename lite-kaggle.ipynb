# %%
# %cd /kaggle/working
# !git clone -q --branch main https://github.com/zetclansu/lite-kaggle
# %cd /kaggle/working/lite-kaggle
# !python launch.py --share --theme dark --api --disable-safe-unpickle --enable-insecure-extension-access --no-half-vae --opt-sdp-attention --disable-console-progressbars
